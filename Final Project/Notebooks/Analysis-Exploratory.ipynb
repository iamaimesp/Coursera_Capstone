# %%
#! pip install seaborn

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [raw]
# analysisfeatures=pd.read_csv('prepared_data/zcta_venuessummary_ct_housing.csv')
# analysisfeatures

# %% [markdown]
# ## Correlation Between Commute Times

# %% [markdown]
# ### Correlation Between the commute time at 6:00 and 6:30

# %%
sns.regplot(x="ct_06:00", y="ct_06:30", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 54.70260650729152)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['ct_06:00'], analysisfeatures['ct_06:30'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9834396062260626  with a P-value of P = 5.400627006935083e-76

# %% [markdown]
# ### Correlation Between the commute time at 6:00 and 7:00

# %%
sns.regplot(x="ct_06:00", y="ct_07:00", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 60.5830463577147)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['ct_06:00'], analysisfeatures['ct_07:00'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9731333240271932  with a P-value of P = 1.3519555581233572e-65

# %% [markdown]
# ### Correlation Between the commute time at 6:00 and 7:30

# %%
sns.regplot(x="ct_06:00", y="ct_07:30", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 64.6717286222063)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['ct_06:00'], analysisfeatures['ct_07:30'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9651476910177562  with a P-value of P = 4.980645259632517e-60

# %% [markdown]
# ### Correlation Between the commute time at 6:00 and 8:00

# %%
sns.regplot(x="ct_06:00", y="ct_08:00", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 65.79070518480262)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['ct_06:00'], analysisfeatures['ct_08:00'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9755067133548697  with a P-value of P = 1.405033231326745e-67

# %% [markdown]
# ### Correlation Between the commute time at 6:00 and 8:30

# %%
sns.regplot(x="ct_06:00", y="ct_08:30", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 62.66132583722394)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['ct_06:00'], analysisfeatures['ct_08:30'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9744899802347942  with a P-value of P = 1.0474610429613259e-66

# %% [markdown]
# ### Correlation Between the commute time at 6:00 and 9:00

# %%
sns.regplot(x="ct_06:00", y="ct_09:00", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 56.487991006674505)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['ct_06:00'], analysisfeatures['ct_09:00'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9692776049261348  with a P-value of P = 1.0051548718319798e-62

# %% [markdown]
# ### Correlation Between the commute time at 6:00 and 9:30

# %%
sns.regplot(x="ct_06:00", y="ct_09:30", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 54.3807658464653)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['ct_06:00'], analysisfeatures['ct_09:30'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9615933586015458  with a P-value of P = 5.865192857063284e-58

# %% [markdown]
# ## Correlation Between Housing Price Indexes

# %% [markdown]
# ### Correlation Between ZHVI for Single Family Homes and Multi-Family Homes

# %%
sns.regplot(x="zhvi_sfh", y="zhvi_mfh", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 1376436.65)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_sfh'], analysisfeatures['zhvi_mfh'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6123431759702423  with a P-value of P = 7.984935886625333e-12

# %% [markdown]
# ### Correlation Between ZHVI for Single Family Homes and 1-Bedroom Homes

# %%
sns.regplot(x="zhvi_sfh", y="zhvi_1bd", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 923986.9)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_sfh'], analysisfeatures['zhvi_1bd'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.48137183633973263  with a P-value of P = 3.028614150775832e-07

# %% [markdown]
# ### Correlation Between ZHVI for Single Family Homes and 2-Bedroom Homes

# %%
sns.regplot(x="zhvi_sfh", y="zhvi_2bd", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 1156828.52226577)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_sfh'], analysisfeatures['zhvi_2bd'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.7802349420925757  with a P-value of P = 4.243572819562576e-22

# %% [markdown]
# ### Correlation Between ZHVI for Single Family Homes and 3-Bedroom Homes

# %%
sns.regplot(x="zhvi_sfh", y="zhvi_3bd", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 1726839.658639763)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_sfh'], analysisfeatures['zhvi_3bd'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8768544223228019  with a P-value of P = 1.4096991691036598e-33

# %% [markdown]
# ### Correlation Between ZHVI for Single Family Homes and 4-Bedroom Homes

# %%
sns.regplot(x="zhvi_sfh", y="zhvi_4bd", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 2141029.8072167668)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_sfh'], analysisfeatures['zhvi_4bd'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9005907040009038  with a P-value of P = 5.769264595921653e-38

# %% [markdown]
# ### Correlation Between ZHVI for Single Family Homes and 5-Bedroom Homes

# %%
sns.regplot(x="zhvi_sfh", y="zhvi_5bd", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 2845372.5070066946)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_sfh'], analysisfeatures['zhvi_5bd'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9289585315417951  with a P-value of P = 5.941902308652282e-45

# %% [markdown]
# ### Correlation Between ZHVI for Single Family Homes and ZRI

# %%
sns.regplot(x="zhvi_sfh", y="zri_all", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 3246.2811819173)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_sfh'], analysisfeatures['zri_all'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.7993361286648901  with a P-value of P = 7.495919535140813e-24

# %% [markdown]
# ### Correlation Between ZHVI for Multi-Family Homes and 1-Bedroom Homes

# %%
sns.regplot(x="zhvi_mfh", y="zhvi_1bd", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 1202817.428698786)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_mfh'], analysisfeatures['zhvi_1bd'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8643764362596372  with a P-value of P = 1.2769086892404907e-31

# %% [markdown]
# ### Correlation Between ZHVI for Multi-Family Homes and 2-Bedroom Homes

# %%
sns.regplot(x="zhvi_mfh", y="zhvi_2bd", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 1872318.996022749)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_mfh'], analysisfeatures['zhvi_2bd'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.776198540562853  with a P-value of P = 9.45880982856273e-22

# %% [markdown]
# ### Correlation Between ZHVI for Multi-Family Homes and Renting Homes

# %%
sns.regplot(x="zhvi_mfh", y="zri_all", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 4208.374865066007)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_mfh'], analysisfeatures['zri_all'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.7691135351166444  with a P-value of P = 3.712615017576243e-21

# %% [markdown]
# ## Correlation Between Commute Time and Housing Indexes

# %% [markdown]
# ### Correlation Between Commute time and ZHVI for Single-Family Homes

# %%
sns.regplot(x="ct_08:00", y="zhvi_sfh", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 1756015.55)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['ct_08:00'], analysisfeatures['zhvi_sfh'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.5608618596130626  with a P-value of P = 8.738628430294799e-10

# %% [markdown]
# ### Correlation Between Commute time and ZHVI for Multi-Family Homes

# %%
sns.regplot(x="ct_08:00", y="zhvi_mfh", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 1376436.65)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['ct_08:00'], analysisfeatures['zhvi_mfh'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.49302853790186774  with a P-value of P = 1.4066119266490787e-07

# %% [markdown]
# ## Correlation Between Commute Time and Venue Count

# %%
sns.regplot(x="ct_08:00", y="venue_count", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 105.4504056103761)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['ct_08:00'], analysisfeatures['venue_count'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.510516448099728  with a P-value of P = 4.213789087441576e-08

# %% [markdown]
# ## Correlation Between Housing Indexes and Venue Count

# %%
sns.regplot(x="zhvi_sfh", y="venue_count", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 104.95)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_sfh'], analysisfeatures['venue_count'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.3446969800364074  with a P-value of P = 0.00038855055737324514

# %%
sns.regplot(x="zhvi_mfh", y="venue_count", data=analysisfeatures)
plt.ylim(0,)
# Out:
# (0.0, 135.6762689492125)

# %%
pearson_coef, p_value = stats.pearsonr(analysisfeatures['zhvi_mfh'], analysisfeatures['venue_count'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.4339160910334663  with a P-value of P = 5.210944626049583e-06
